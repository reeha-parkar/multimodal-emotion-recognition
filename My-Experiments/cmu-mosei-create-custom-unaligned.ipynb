# %%
# %pwd
# Out:
# '/cephfs/volumes/hpc_data_usr/k24083007/2070c87e-fe07-4f03-a6c4-cae0de8ce617'

# %%
# %cd cmu-mosei-experiments/CMU-MultimodalSDK-Tutorials/
# Out:
# /cephfs/volumes/hpc_data_usr/k24083007/2070c87e-fe07-4f03-a6c4-cae0de8ce617/cmu-mosei-experiments/CMU-MultimodalSDK-Tutorials

# %%
# !nvidia-smi
# Out:
# Wed Jul 16 14:26:04 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.230.02             Driver Version: 535.230.02   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          On  | 00000000:00:07.0 Off |                    0 |
# | N/A   31C    P0              41W / 300W |      0MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
import sys
import numpy as np
from mmsdk import mmdatasdk as md
from constants.paths import SDK_PATH, DATA_PATH


import torch
import pickle
import requests
import re
from collections import defaultdict
from typing import Dict, List, Tuple, Any
import json

# Visualization and analysis
import matplotlib.pyplot as plt
import seaborn as sns

# For deep inspection of dataset structures
import inspect
from pprint import pprint

# %%
pt_data_path = '../CARAT/data/train_valid_test.pt'
print(f"Data file exists: {os.path.exists(pt_data_path)}")

if os.path.exists(pt_data_path):
    print(f"File size: {os.path.getsize(pt_data_path) / (1024*1024):.2f} MB")
    
    # Load the data
    try:
        data = torch.load(pt_data_path, map_location='cuda:0')
        print(f"Data keys: {list(data.keys())}")
        if 'train' in data:
            print(f"Train data keys: {list(data['train'].keys())}")
    except Exception as e:
        print(f"Error loading data: {e}")
# Out:
# Data file exists: True
# File size: 5274.60 MB
# Data keys: ['settings', 'dict', 'train', 'valid', 'test']
# Train data keys: ['src-text', 'src-visual', 'src-audio', 'tgt']

# %%
# Ensure SDK is in path
sys.path.append(SDK_PATH)

# Make sure DATA_PATH exists
if not os.path.exists(DATA_PATH):
    print(f"Error: DATA_PATH does not exist: {DATA_PATH}")
    print("Please modify DATA_PATH to point to your .csd files directory")
    # os.makedirs(DATA_PATH, exist_ok=True)
else:
    data_files = os.listdir(DATA_PATH)
    print("Available data files:")
    print('\n'.join(data_files))
# Out:
# Available data files:
# CMU_MOSEI_COVAREP.csd
# CMU_MOSEI_TimestampedWords.csd
# CMU_MOSEI_OpenFace2.csd
# CMU_MOSEI_VisualFacet42.csd
# CMU_MOSEI_TimestampedWordVectors.csd
# CMU_MOSEI_TimestampedPhones.csd
# CMU_MOSEI_Labels.csd

# %%
text_field = 'CMU_MOSEI_TimestampedWordVectors'
visual_field = 'CMU_MOSEI_VisualFacet42'
acoustic_field = 'CMU_MOSEI_COVAREP'

# Define the features to load
features = [
    text_field, 
    visual_field, 
    acoustic_field
]

recipe = {feat: os.path.join(DATA_PATH, feat) + '.csd' for feat in features}

# Load the dataset
try:
    dataset = md.mmdataset(recipe)
    print("Dataset loaded successfully!")
except Exception as e:
    print(f"Error loading dataset: {e}")
    print("Available files:", data_files)
# Out:
# [2025-07-04 09:28:29.043] | Success | Computational sequence read from file ./data/CMU_MOSEI_TimestampedWordVectors.csd ...
# [2025-07-04 09:28:29.168] | Status  | Checking the integrity of the <glove_vectors> computational sequence ...
# [2025-07-04 09:28:29.168] | Status  | Checking the format of the data in <glove_vectors> computational sequence ...
# [2025-07-04 09:28:30.176] | Success | <glove_vectors> computational sequence data in correct format.
# [2025-07-04 09:28:30.176] | Status  | Checking the format of the metadata in <glove_vectors> computational sequence ...
# [2025-07-04 09:28:30.176] | Warning | <glove_vectors> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:28:30.177] | Success | Computational sequence read from file ./data/CMU_MOSEI_VisualFacet42.csd ...
# [2025-07-04 09:28:30.261] | Status  | Checking the integrity of the <FACET 4.2> computational sequence ...
# [2025-07-04 09:28:30.261] | Status  | Checking the format of the data in <FACET 4.2> computational sequence ...
# [2025-07-04 09:28:31.224] | Success | <FACET 4.2> computational sequence data in correct format.
# [2025-07-04 09:28:31.224] | Status  | Checking the format of the metadata in <FACET 4.2> computational sequence ...
# [2025-07-04 09:28:31.224] | Warning | <FACET 4.2> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:28:31.225] | Success | Computational sequence read from file ./data/CMU_MOSEI_COVAREP.csd ...
# [2025-07-04 09:28:31.306] | Status  | Checking the integrity of the <COVAREP> computational sequence ...
# [2025-07-04 09:28:31.306] | Status  | Checking the format of the data in <COVAREP> computational sequence ...
# [2025-07-04 09:28:32.263] | Success | <COVAREP> computational sequence data in correct format.
# [2025-07-04 09:28:32.263] | Status  | Checking the format of the metadata in <COVAREP> computational sequence ...
# [2025-07-04 09:28:32.263] | Warning | <COVAREP> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:28:32.263] | Success | Dataset initialized successfully ...
# Dataset loaded successfully!

# %%
# "Note that the SDK always expect collapse functions with two arguments: `intervals` and `features`." 
# "Even if you don't use intervals (as is in the case below) you still need to define your function"

# def preserve_features(intervals: np.array, features: np.array) -> np.array:
#     """
#     Preserves temporal information while respecting alignment bins
    
#     """
#     if features.shape[0] == 0:
#         return features
#     elif features.shape[0] == 1:
#         return features[0]  # Single feature - return as-is
#     else:
#         # Multiple features in bin - take the median preserving the peak of the distribution
#         # This keeps the middle frame as the representative feature
#         mid_idx = features.shape[0] // 2
#         return features[mid_idx]
    
# dataset.align(text_field, collapse_functions=[preserve_features])

# %%
# Add labels and align to them
label_field = 'CMU_MOSEI_Labels'

# Add labels to the dataset
label_recipe = {label_field: os.path.join(DATA_PATH, label_field + '.csd')}

try:
    # Add the labels to the dataset
    dataset.add_computational_sequences(label_recipe, destination=None)
    # # Align to labels to get labeled segments
    # dataset.align(label_field)
    print("Labels added successfully!")

except Exception as e:
    print(f"Error adding labels: {e}")
    print("Available files:", data_files)
# Out:
# [2025-07-04 09:28:35.460] | Success | Computational sequence read from file ./data/CMU_MOSEI_Labels.csd ...
# [2025-07-04 09:28:35.527] | Status  | Checking the integrity of the <All Labels> computational sequence ...
# [2025-07-04 09:28:35.527] | Status  | Checking the format of the data in <All Labels> computational sequence ...
# [2025-07-04 09:28:36.330] | Success | <All Labels> computational sequence data in correct format.
# [2025-07-04 09:28:36.330] | Status  | Checking the format of the metadata in <All Labels> computational sequence ...
# [2025-07-04 09:28:36.330] | Warning | <All Labels> computational sequence does not have all the required metadata ... continuing
# Labels added successfully!

# %%
#Testing out without collapse_fns
dataset.align(label_field, collapse_functions=None)

print("Alignment done")
# Out:
# [2025-07-04 09:28:36.385] | Status  | Unify was called ...
# [2025-07-04 09:28:36.393] | Warning | 273510 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.394] | Warning | 74115 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.395] | Warning | 110983 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.397] | Warning | 118639 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.398] | Warning | 56853 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.399] | Warning | 226602 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.400] | Warning | 21285 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.402] | Warning | 26110 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.403] | Warning | 298459 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.404] | Warning | 30036 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.406] | Warning | 275603 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.407] | Warning | 110003 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.408] | Warning | 38387 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.409] | Warning | 224649 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.411] | Warning | 188004 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.412] | Warning | 219614 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.413] | Warning | 204792 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.414] | Warning | 110824 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.415] | Warning | 118583 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.417] | Warning | 125868 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.418] | Warning | 91996 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.419] | Warning | 46592 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.420] | Warning | 58151 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.422] | Warning | 280951 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.423] | Warning | 75393 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.424] | Warning | 47797 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.425] | Warning | 107456 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.426] | Warning | 188062 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.428] | Warning | 50478 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.429] | Warning | rLNY4-FWt5c entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.430] | Warning | 250343 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.431] | Warning | 22360 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.432] | Warning | 270993 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.434] | Warning | 124190 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.435] | Warning | 35692 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.436] | Warning | 136416 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.437] | Warning | 60308 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.439] | Warning | 218912 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.440] | Warning | 216831 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.441] | Warning | 21844 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.442] | Warning | 176266 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.444] | Warning | 228925 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.445] | Warning | 109909 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.446] | Warning | 224622 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.447] | Warning | 251251 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.448] | Warning | 27880 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.450] | Warning | 91166 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.451] | Warning | 220809 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.452] | Warning | 243056 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.453] | Warning | 133888 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.454] | Warning | 84772 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.456] | Warning | 30762 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.457] | Warning | 266861 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.458] | Warning | 48019 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.459] | Warning | 219350 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.461] | Warning | 76819 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.462] | Warning | 100232 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.463] | Warning | 99331 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.464] | Warning | 73360 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.466] | Warning | 71459 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.467] | Warning | 95147 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.468] | Warning | 59712 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.469] | Warning | 22649 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.470] | Warning | 276771 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.472] | Warning | 40129 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.473] | Warning | 74197 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.474] | Warning | 246216 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.475] | Warning | 100961 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.476] | Warning | 49029 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.478] | Warning | 299754 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.479] | Warning | 26690 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.480] | Warning | 98513 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.481] | Warning | 93843 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.482] | Warning | 58554 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.484] | Warning | 111363 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.485] | Warning | 253709 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.486] | Warning | 49417 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.487] | Warning | 90667 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.488] | Warning | 193514 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.490] | Warning | 18938 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.491] | Warning | 40367 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.492] | Warning | 26808 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.493] | Warning | 323217 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.495] | Warning | 17874 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.496] | Warning | 19850 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.497] | Warning | 172075 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.498] | Warning | 116461 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.499] | Warning | 86494 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.501] | Warning | 58795 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.502] | Warning | 301321 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.503] | Warning | 206621 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.504] | Warning | 301320 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.505] | Warning | 89184 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.507] | Warning | 42946 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.508] | Warning | 219627 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.509] | Warning | 62438 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.510] | Warning | 63956 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.511] | Warning | 79203 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.513] | Warning | 196364 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.514] | Warning | 113162 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.515] | Warning | 75892 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.516] | Warning | 91574 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.517] | Warning | 179797 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.518] | Warning | 228561 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.520] | Warning | 294226 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.521] | Warning | 238567 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.522] | Warning | 248400 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.523] | Warning | 230422 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.524] | Warning | 17769 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.526] | Warning | 50479 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.527] | Warning | 95388 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.528] | Warning | 79019 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.529] | Warning | 98505 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.530] | Warning | 187566 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.532] | Warning | 247538 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.534] | Warning | 22719 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.535] | Warning | 215343 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.536] | Warning | 274917 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.537] | Warning | 204519 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.538] | Warning | 22798 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.540] | Warning | 255205 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.541] | Warning | 134298 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.542] | Warning | 241124 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.543] | Warning | 341763 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.544] | Warning | 126505 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.545] | Warning | 17622 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.547] | Warning | 245207 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.548] | Warning | 238624 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.549] | Warning | 34684 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.550] | Warning | 29758 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.551] | Warning | 71736 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.552] | Warning | 254488 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.554] | Warning | 101513 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.555] | Warning | 111104 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.556] | Warning | 98562 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.557] | Warning | 47939 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.558] | Warning | 238042 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.559] | Warning | 234641 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.561] | Warning | 22901 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.562] | Warning | 135658 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.563] | Warning | 26115 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.564] | Warning | 159031 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.565] | Warning | 193921 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.566] | Warning | 210555 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.568] | Warning | 97076 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.569] | Warning | 210240 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.570] | Warning | 223883 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.571] | Warning | 87163 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.572] | Warning | 341382 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.573] | Warning | 71987 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.575] | Warning | 34640 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.576] | Warning | 258672 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.577] | Warning | 233405 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.578] | Warning | 224271 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.579] | Warning | 224498 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.580] | Warning | 60402 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.582] | Warning | 79925 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.583] | Warning | dZFV0lyedX4 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.584] | Warning | 125726 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.585] | Warning | 79858 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.586] | Warning | 101880 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.587] | Warning | 112029 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.588] | Warning | 27881 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.590] | Warning | 133201 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.591] | Warning | 78752 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.592] | Warning | 221104 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.593] | Warning | 98649 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.595] | Warning | 97289 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.596] | Warning | 231412 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.598] | Warning | 57598 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.599] | Warning | 41032 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.600] | Warning | 95887 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.601] | Warning | 223333 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.602] | Warning | 233940 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.604] | Warning | 254216 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.605] | Warning | 179875 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.606] | Warning | 98636 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.607] | Warning | 306700 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.608] | Warning | 261052 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.609] | Warning | 188825 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.611] | Warning | 237385 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.612] | Warning | 75441 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.613] | Warning | 122581 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.614] | Warning | 114945 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.615] | Warning | 58097 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.616] | Warning | 60328 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.618] | Warning | 27857 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.619] | Warning | 36116 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.628] | Warning | 36060 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.629] | Warning | 265811 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.630] | Warning | 58096 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.633] | Warning | 247764 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.634] | Warning | 27886 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.635] | Warning | 127908 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.636] | Warning | 49264 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.637] | Warning | 89266 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.639] | Warning | 267354 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.640] | Warning | 220832 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.641] | Warning | 93807 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.642] | Warning | 16145 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.643] | Warning | 88792 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.644] | Warning | 193924 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.646] | Warning | 116219 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.647] | Warning | 140315 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.648] | Warning | 260199 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.649] | Warning | 192978 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.650] | Warning | 41026 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.651] | Warning | 96377 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.653] | Warning | 7l3BNtSE0xc entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.654] | Warning | 203806 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.655] | Warning | 246789 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.656] | Warning | 273032 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.657] | Warning | 24602 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.658] | Warning | 267092 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.659] | Warning | 229296 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.661] | Warning | 96595 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.662] | Warning | 123986 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.663] | Warning | 84670 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.664] | Warning | 61247 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.665] | Warning | HK0U0bIN-cw entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.666] | Warning | 342407 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.667] | Warning | 35934 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.669] | Warning | jHB9kiH6Vas entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.669] | Warning | 88881 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.671] | Warning | 116481 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.672] | Warning | 22344 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.673] | Warning | 46826 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.674] | Warning | 66505 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.675] | Warning | 50444 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.677] | Warning | 213207 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.678] | Warning | 280584 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.679] | Warning | 232464 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.680] | Warning | 102534 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.681] | Warning | 76104 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.682] | Warning | 29771 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.684] | Warning | 49903 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.685] | Warning | 137455 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.686] | Warning | 219600 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.687] | Warning | 68828 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.688] | Warning | 31544 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.690] | Warning | 30171 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.691] | Warning | 272817 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.692] | Warning | 70299 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.693] | Warning | 22335 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.694] | Warning | 57295 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.695] | Warning | 136234 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.697] | Warning | 110794 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.698] | Warning | 290062 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.699] | Warning | 91292 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.700] | Warning | 65939 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.701] | Warning | 219605 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.703] | Warning | 116202 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.704] | Warning | 274073 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.705] | Warning | 19915 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.706] | Warning | 111734 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.707] | Warning | 368460 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.709] | Warning | 245926 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.710] | Warning | 190599 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.711] | Warning | 91002 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.712] | Warning | 10124 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.713] | Warning | 265302 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.714] | Warning | 94439 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.715] | Warning | 33436 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.717] | Warning | 231453 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.718] | Warning | 95205 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.719] | Warning | 238545 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.720] | Warning | 270439 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.721] | Warning | 239242 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.722] | Warning | 252919 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.723] | Warning | 48724 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.725] | Warning | 27888 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.726] | Warning | 69307 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.727] | Warning | 222605 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.736] | Warning | 224292 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.737] | Warning | 203466 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.739] | Warning | 207867 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.740] | Warning | 201980 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.741] | Warning | 110209 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.742] | Warning | 112172 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.743] | Warning | 223338 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.745] | Warning | 121427 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.746] | Warning | 193894 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.747] | Warning | 127490 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.748] | Warning | 172048 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.749] | Warning | 74204 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.750] | Warning | 17811 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.752] | Warning | 109524 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.753] | Warning | 262341 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.754] | Warning | 127622 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.755] | Warning | 101733 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.756] | Warning | 24508 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.757] | Warning | 93119 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.758] | Warning | 224472 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.760] | Warning | 82666 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.761] | Warning | 113491 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.762] | Warning | 128600 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.763] | Warning | 96106 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.764] | Warning | 160225 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.765] | Warning | 224325 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.767] | Warning | 69870 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.768] | Warning | 28412 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.769] | Warning | 211611 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.770] | Warning | 195575 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.771] | Warning | 35684 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.772] | Warning | 341983 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.774] | Warning | 121759 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.775] | Warning | 61277 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.776] | Warning | 178163 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.777] | Warning | 60428 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.778] | Warning | 101635 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.779] | Warning | 327282 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.781] | Warning | 105963 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.782] | Warning | 43469 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.783] | Warning | 34989 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.784] | Warning | 218757 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.785] | Warning | 91284 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.786] | Warning | 10397 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.788] | Warning | 21696 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.789] | Warning | 302220 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.790] | Warning | 83119 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.791] | Warning | 48219 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.792] | Warning | 93828 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.793] | Warning | 227556 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.795] | Warning | 98155 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.796] | Warning | OPuu8EknNqk entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.797] | Warning | 190726 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.799] | Warning | 28142 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.800] | Warning | 90008 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.801] | Warning | 239180 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.802] | Warning | 63841 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.803] | Warning | 68721 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.805] | Warning | 246117 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.806] | Warning | 43342 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.807] | Warning | 158832 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.808] | Warning | 125698 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.809] | Warning | 32459 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.810] | Warning | 110690 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.811] | Warning | 108573 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.813] | Warning | 57231 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.814] | Warning | 120342 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.815] | Warning | 207977 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.816] | Warning | 22785 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.817] | Warning | 263889 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.818] | Warning | 60405 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.819] | Warning | 248024 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.821] | Warning | 93845 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.822] | Warning | 199215 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.823] | Warning | 114419 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.824] | Warning | 106037 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.825] | Warning | 19664 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.826] | Warning | 370050 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.828] | Warning | 224648 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.829] | Warning | 370404 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.830] | Warning | 229808 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.831] | Warning | 118354 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.832] | Warning | Jv4CxSgWP2k entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.833] | Warning | 37462 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.834] | Warning | 100446 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.835] | Warning | 74532 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.837] | Warning | 222510 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.838] | Warning | 268536 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.839] | Warning | 21735 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.840] | Warning | 91252 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.841] | Warning | 112674 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.842] | Warning | 259857 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.843] | Warning | 114016 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.845] | Warning | 40247 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.846] | Warning | 206179 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.847] | Warning | 217395 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.848] | Warning | 242166 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.849] | Warning | 220550 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.850] | Warning | 113369 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.852] | Warning | 282985 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.853] | Warning | 81563 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.854] | Warning | 29920 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.855] | Warning | 213375 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.856] | Warning | 87434 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.857] | Warning | 52067 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.859] | Warning | 50302 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.860] | Warning | 45860 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.861] | Warning | 105507 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.862] | Warning | 26113 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.863] | Warning | 69234 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.873] | Warning | 238858 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.874] | Warning | 233880 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.876] | Warning | 46503 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.877] | Warning | 102424 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.878] | Warning | 84924 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.880] | Warning | 43444 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.881] | Warning | 104739 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.891] | Warning | 188815 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.892] | Warning | 208465 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.893] | Warning | 204378 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.894] | Warning | 22277 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.895] | Warning | 230692 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.897] | Warning | 24814 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.898] | Warning | 22884 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.899] | Warning | 120363 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.900] | Warning | 114845 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.901] | Warning | 40266 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.902] | Warning | 46860 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.904] | Warning | 132476 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.905] | Warning | 342197 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.906] | Warning | 28191 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.907] | Warning | 243797 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.908] | Warning | 199227 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.909] | Warning | 241178 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.911] | Warning | 57294 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.912] | Warning | 93116 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.913] | Warning | 193322 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.914] | Warning | 103311 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.915] | Warning | 33272 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.916] | Warning | 66623 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.918] | Warning | 46663 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.919] | Warning | 172060 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.920] | Warning | 110543 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.921] | Warning | 229637 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.922] | Warning | 181978 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.923] | Warning | vi0FsBCqfRE entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.924] | Warning | 33089 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.925] | Warning | 97908 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.926] | Warning | 34984 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.928] | Warning | 7156 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.929] | Warning | 207964 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.930] | Warning | 189856 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.931] | Warning | 136647 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.932] | Warning | 207118 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.933] | Warning | FrS-6P6FdCM entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.934] | Warning | 81707 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.935] | Warning | 121584 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.936] | Warning | 49073 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.938] | Warning | 24157 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.939] | Warning | 78398 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.941] | Warning | 105537 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.942] | Warning | 119397 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.943] | Warning | 219460 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.944] | Warning | 204085 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.946] | Warning | 50307 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.947] | Warning | 178941 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.948] | Warning | 47056 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.950] | Warning | 80640 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.951] | Warning | 69268 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.953] | Warning | 5jGUBcStsZs entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.953] | Warning | 224285 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.955] | Warning | PEBwwe0PLZ8 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.955] | Warning | 207958 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.957] | Warning | 106973 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.958] | Warning | 238597 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.959] | Warning | 74447 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.960] | Warning | 223885 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.961] | Warning | 100367 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.962] | Warning | 28182 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.963] | Warning | 40970 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.964] | Warning | 52160 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.965] | Warning | 81371 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.967] | Warning | 238803 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.968] | Warning | 234406 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.969] | Warning | 30646 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.970] | Warning | 219620 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.971] | Warning | 209869 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.972] | Warning | 65068 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.973] | Warning | 96694 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.974] | Warning | 105906 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.975] | Warning | 192827 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.977] | Warning | 270771 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.978] | Warning | 48300 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.979] | Warning | 268127 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.980] | Warning | 186643 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.981] | Warning | 210098 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.982] | Warning | 53233 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.983] | Warning | 233431 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.984] | Warning | 258802 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.985] | Warning | 23343 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.987] | Warning | 246798 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.988] | Warning | 94525 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.989] | Warning | 247108 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.990] | Warning | 137920 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.991] | Warning | 132570 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.992] | Warning | 206148 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.993] | Warning | 263444 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.994] | Warning | 176541 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.995] | Warning | 268258 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.997] | Warning | 205268 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.998] | Warning | 94532 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:36.999] | Warning | 43428 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.000] | Warning | 201497 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.001] | Warning | 50306 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.003] | Warning | 236108 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.004] | Warning | 107182 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.005] | Warning | 61557 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.006] | Warning | 274185 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.008] | Warning | 101747 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.009] | Warning | 60983 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.010] | Warning | 129728 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.011] | Warning | 30858 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.012] | Warning | 172050 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.013] | Warning | 36164 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.014] | Warning | 116221 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.015] | Warning | 22305 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.016] | Warning | 105553 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.017] | Warning | 7155 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.019] | Warning | 279373 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.020] | Warning | 224238 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.021] | Warning | 27863 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.022] | Warning | 103114 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.023] | Warning | 121117 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.024] | Warning | 44457 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.025] | Warning | 191941 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.026] | Warning | 88077 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.027] | Warning | 96700 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.028] | Warning | 196665 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.029] | Warning | 60351 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.031] | Warning | 74268 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.032] | Warning | 61035 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.033] | Warning | 118573 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.034] | Warning | 193093 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.035] | Warning | 49962 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.036] | Warning | 172044 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.037] | Warning | 191616 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.038] | Warning | 158855 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.039] | Warning | 31392 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.040] | Warning | 101281 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.041] | Warning | eLjNLHkvxH4 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.042] | Warning | 236306 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.043] | Warning | 38154 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.045] | Warning | 101708 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.046] | Warning | 114006 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.047] | Warning | 187033 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.048] | Warning | 115134 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.049] | Warning | 42426 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.050] | Warning | 535523 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.051] | Warning | 16530 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.052] | Warning | 1nXhAjuICTA entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.053] | Warning | 96337 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.054] | Warning | 183364 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.056] | Warning | 21727 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.057] | Warning | 223377 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.058] | Warning | 23289 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.059] | Warning | 187775 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.060] | Warning | 280794 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.061] | Warning | 46808 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.062] | Warning | 19573 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.063] | Warning | 197232 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.065] | Warning | 59302 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.066] | Warning | 97463 entry is not shared among all sequences, removing it ...
# [2025-07-04 09:28:37.067] | Success | Unify completed ...
# [2025-07-04 09:28:37.067] | Status  | Pre-alignment based on <CMU_MOSEI_Labels> computational sequence started ...
# [2025-07-04 09:28:52.580] | Status  | Pre-alignment done for <CMU_MOSEI_TimestampedWordVectors> ...
# [2025-07-04 09:29:09.581] | Status  | Pre-alignment done for <CMU_MOSEI_VisualFacet42> ...
# [2025-07-04 09:30:20.809] | Status  | Pre-alignment done for <CMU_MOSEI_COVAREP> ...
# [2025-07-04 09:30:21.731] | Status  | Alignment starting ...
# [2025-07-04 09:31:38.981] | Success | Alignment to <CMU_MOSEI_Labels> complete.
# [2025-07-04 09:31:38.981] | Status  | Replacing dataset content with aligned computational sequences
# [2025-07-04 09:31:39.092] | Success | Initialized empty <CMU_MOSEI_TimestampedWordVectors> computational sequence.
# [2025-07-04 09:31:39.098] | Status  | Checking the format of the data in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2025-07-04 09:31:39.142] | Success | <CMU_MOSEI_TimestampedWordVectors> computational sequence data in correct format.
# [2025-07-04 09:31:39.144] | Status  | Checking the format of the metadata in <CMU_MOSEI_TimestampedWordVectors> computational sequence ...
# [2025-07-04 09:31:39.145] | Warning | <CMU_MOSEI_TimestampedWordVectors> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:31:39.145] | Success | Initialized empty <CMU_MOSEI_VisualFacet42> computational sequence.
# [2025-07-04 09:31:39.145] | Status  | Checking the format of the data in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2025-07-04 09:31:39.184] | Success | <CMU_MOSEI_VisualFacet42> computational sequence data in correct format.
# [2025-07-04 09:31:39.188] | Status  | Checking the format of the metadata in <CMU_MOSEI_VisualFacet42> computational sequence ...
# [2025-07-04 09:31:39.190] | Warning | <CMU_MOSEI_VisualFacet42> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:31:39.191] | Success | Initialized empty <CMU_MOSEI_COVAREP> computational sequence.
# [2025-07-04 09:31:39.204] | Status  | Checking the format of the data in <CMU_MOSEI_COVAREP> computational sequence ...
# [2025-07-04 09:31:39.258] | Success | <CMU_MOSEI_COVAREP> computational sequence data in correct format.
# [2025-07-04 09:31:39.264] | Status  | Checking the format of the metadata in <CMU_MOSEI_COVAREP> computational sequence ...
# [2025-07-04 09:31:39.266] | Warning | <CMU_MOSEI_COVAREP> computational sequence does not have all the required metadata ... continuing
# [2025-07-04 09:31:39.267] | Success | Initialized empty <CMU_MOSEI_Labels> computational sequence.
# [2025-07-04 09:31:39.267] | Status  | Checking the format of the data in <CMU_MOSEI_Labels> computational sequence ...
# [2025-07-04 09:31:39.321] | Success | <CMU_MOSEI_Labels> computational sequence data in correct format.
# [2025-07-04 09:31:39.321] | Status  | Checking the format of the metadata in <CMU_MOSEI_Labels> computational sequence ...
# [2025-07-04 09:31:39.321] | Warning | <CMU_MOSEI_Labels> computational sequence does not have all the required metadata ... continuing
# Alignment done

# %%
# Total segments of each modality
text_segments = len(list(dataset[text_field].keys()))
visual_segments = len(list(dataset[visual_field].keys()))
acoustic_segments = len(list(dataset[acoustic_field].keys()))
label_segments = len(list(dataset[label_field].keys()))

print(f"Text segments: {text_segments}")
print(f"Visual segments: {visual_segments}")
print(f"Acoustic segments: {acoustic_segments}")
print(f"Label segments: {label_segments}")
# Out:
# Text segments: 23248
# Visual segments: 23240
# Acoustic segments: 23248
# Label segments: 23248

# %%
# Looking at 5 sample segments:
sample_segments = list(dataset[label_field].keys())[:5]
for segment in sample_segments:
    try:
        text_shape = dataset[text_field][segment]['features'].shape
        visual_shape = dataset[visual_field][segment]['features'].shape
        acoustic_shape = dataset[acoustic_field][segment]['features'].shape
        label_shape = dataset[label_field][segment]['features'].shape
        
        print(f"\nSegment: {segment}")
        print(f"  Text: {text_shape}, Visual: {visual_shape}, Acoustic: {acoustic_shape}, Label: {label_shape}")
    except KeyError as e:
        print(f"Missing data for segment {segment}: {e}")
# Out:
# Segment: --qXJuDtHPw[0]
#   Text: (22, 300), Visual: (215, 35), Acoustic: (714, 74), Label: (1, 7)
#
# Segment: -3g5yACwYnA[0]
#   Text: (55, 300), Visual: (535, 35), Acoustic: (1781, 74), Label: (1, 7)
#
# Segment: -3g5yACwYnA[1]
#   Text: (22, 300), Visual: (162, 35), Acoustic: (539, 74), Label: (1, 7)
#
# Segment: -3g5yACwYnA[2]
#   Text: (23, 300), Visual: (277, 35), Acoustic: (922, 74), Label: (1, 7)
#
# Segment: -3g5yACwYnA[3]
#   Text: (42, 300), Visual: (430, 35), Acoustic: (1432, 74), Label: (1, 7)

# %%
non_aligned_data = {
    'train': defaultdict(list),
    'val': defaultdict(list), 
    'test': defaultdict(list)
}

# Regex to extract video ID from segment names
pattern = re.compile(r'(.*)\[.*\]')

# Standard CMU-MOSEI splits from mmdatasdk
DATASET = md.cmu_mosei
train_split = set(DATASET.standard_folds.standard_train_fold)
val_split = set(DATASET.standard_folds.standard_valid_fold)
test_split = set(DATASET.standard_folds.standard_test_fold)

# %%
# Check the feature dimensions of all segments for all modalities

def review_features_dim(features, target_dim):
    """
    Sequence processing based on target dimension for respective labels
    """
    padded = False

    if features.size == 0:
        return features, padded
    # For 2D arrays (mostly t, a, v which are sequences of features)
    if len(features.shape) == 2:
        if features.shape[1] == target_dim:
            return features, False
        elif features.shape[1] > target_dim:
            # Truncate to target dimension
            padded = True
            return features[:, :target_dim], padded
        else:
            # Pad to target dimension
            padded = True
            padding = np.zeros((features.shape[0], target_dim - features.shape[1]), dtype=np.float32)
            return np.hstack([features, padding]), padded
        
    # For 1D arrays (labels or single feature sequences)
    elif len(features.shape) == 1:
        current_dim = features.shape[0]
        if current_dim == target_dim:
            return features, padded
        elif current_dim > target_dim:
            padded = True
            return features[:target_dim], padded
        else:
            padded = True
            padding = np.zeros(target_dim - current_dim, dtype=np.float32)
            return np.hstack([features, padding]), padded
    
    # Unknown shape
    else:
        print(f"Warning: Unsupported feature shape {features.shape}. Returning as is.")
        return features, padded

    

# Function to only check audio features and return come flags if they have nan or inf values
def process_audio_features(audio_features):
    """
    Check if audio features contain NaN or Inf/-Inf values and replace them
    """
    audio_features = np.nan_to_num(audio_features)
    # audio_features[audio_features == -np.inf] = 0.0
    # audio_features[audio_features == np.inf] = 0.0

    return audio_features, np.isnan(audio_features).any(), np.isinf(audio_features).any()

# %%
def process_labels(label_features, target_dim=7):
    """
    CMU-MOSEI original label format: [sentiment, happy, sad, anger, surprise, disgust, fear] 
    CARAT needs only 6 emotions and that too in a multi-hot encoding format 
    """
    # Convert to numpy array if not already
    if isinstance(label_features, list):
        label_features = np.array(label_features)
    else:
        # Ensure we have 7 dimensions
        if label_features.shape[-1] == target_dim:
            emotion_labels = label_features.flatten()[1:7]
            emotion_labels = (emotion_labels > 0.0).astype(np.float32)
            return emotion_labels # Return first 6 emotions
        elif label_features.shape[-1] == 6:
            return label_features  # Already in correct format
        else:
            print(f"Warning: Unexpected label shape {label_features.shape}. Expected 6 or 7 dimensions.")
            return None

# %%
stats = {
        'processed_count': 0, 
        'missing_data_count': 0, 
        'empty_features_count': 0, 
        'wrong_splits_count': 0,
        'dimension_issues_count': 0
    }

all_segment_keys = list(dataset[label_field].keys())
total_segments = len(all_segment_keys)
print(f"Processing {total_segments} segments...")


for segment_key in all_segment_keys:
    try:
        # Extracting video ids for determining splits
        vid_match = re.search(pattern, segment_key)
        if not vid_match:
            stats['wrong_splits_count'] += 1
            continue
        vid = vid_match.group(1)

        # Extract features for this segment (keeping original lengths)
        text_features = dataset[text_field][segment_key]['features'].astype(np.float32)
        visual_features = dataset[visual_field][segment_key]['features'].astype(np.float32)
        acoustic_features = dataset[acoustic_field][segment_key]['features'].astype(np.float32)
        label_features = dataset[label_field][segment_key]['features'].astype(np.float32)

        # Show original (intervals, dimensions) for each modality
        # print(f"\nOriginal shapes for segment {segment_key}:")
        # print(f"  Text: {text_features.shape}, Acoustic: {acoustic_features.shape}, Visual: {visual_features.shape}, Label: {label_features.shape}")

        # Empty features cehck
        if (text_features.size == 0 or visual_features.size == 0 or acoustic_features.size == 0 or label_features.size == 0):
            stats['empty_features_count'] += 1
            continue

        # Process each modality
        text_features, text_dim_mismatch = review_features_dim(text_features, target_dim=300)
        acoustic_features, audio_dim_mismatch = review_features_dim(acoustic_features, target_dim=74)
        visual_features, visual_dim_mismatch = review_features_dim(visual_features, target_dim=35)
        label_features, label_dim_mismatch = review_features_dim(label_features, target_dim=7)

        # print(f"\n Processed segment: {segment_key}")
        # print(f"  Text: {text_features.shape}, Acoustic: {acoustic_features.shape}, Visual: {visual_features.shape}, Label: {label_features.shape}")
        if (text_dim_mismatch or audio_dim_mismatch or visual_dim_mismatch or label_dim_mismatch):
            print(f"  Dimension mismatch")
            stats['dimension_issues_count'] += 1
            continue

        audio_features, nan, inf = process_audio_features(acoustic_features)
        if nan or inf:
            print(f"  Warning: Audio features for segment {segment_key} contain NaN or Inf values")
            stats['empty_features_count'] += 1
            continue

        # Determine split
        if vid in train_split:
            split = 'train'
        elif vid in val_split:
            split = 'val'  
        elif vid in test_split:
            split = 'test'
        else:
            stats['wrong_splits_count'] += 1
            continue
        
        # Processing labels
        emotion_labels = process_labels(label_features, target_dim=7)
        if emotion_labels is None:
            stats['missing_data_count'] += 1
            continue
        
        stats['processed_count'] += 1
        
        # Store in CARAT format
        non_aligned_data[split]['src-text'].append(text_features)
        non_aligned_data[split]['src-audio'].append(acoustic_features)
        non_aligned_data[split]['src-visual'].append(visual_features)
        non_aligned_data[split]['tgt'].append(emotion_labels)

    except Exception as e:
        print(f"Segment {segment_key} is missing some data: {e}")
        stats['missing_data_count'] += 1
        continue

# Summary: 
print("\n---------------------- Summary ----------------------")
print(f"Processed {stats['processed_count']} segments out of {total_segments} total segments.")
print(f"Missing data in {stats['missing_data_count']} segments.")   
print(f"Empty features in {stats['empty_features_count']} segments.")
print(f"Wrong splits in {stats['wrong_splits_count']} segments.")
print(f"Dimension issues in {stats['dimension_issues_count']} segments.")

# print(stats)
# Out:
# Processing 23248 segments...
# Segment HuIKyKkEL0Q[0] is missing some data: 'HuIKyKkEL0Q[0]'
# Segment JGEEA_JVriE[1] is missing some data: 'JGEEA_JVriE[1]'
# Segment JGEEA_JVriE[2] is missing some data: 'JGEEA_JVriE[2]'
# Segment JGEEA_JVriE[3] is missing some data: 'JGEEA_JVriE[3]'
# Segment aa0J1AXSseY[4] is missing some data: 'aa0J1AXSseY[4]'
# Segment aa0J1AXSseY[5] is missing some data: 'aa0J1AXSseY[5]'
# Segment aa0J1AXSseY[6] is missing some data: 'aa0J1AXSseY[6]'
# Segment zsRTbbKlsEg[0] is missing some data: 'zsRTbbKlsEg[0]'
#
# ---------------------- Summary ----------------------
# Processed 22852 segments out of 23248 total segments.
# Missing data in 8 segments.
# Empty features in 0 segments.
# Wrong splits in 388 segments.
# Dimension issues in 0 segments.

# %%
print("\n--------- Non-Aligned Data -------------")
# Check the structure of non-aligned data and first 5 key value entries
print(f"Train segments: {len(non_aligned_data['train']['src-text'])}")
print(f"Validation segments: {len(non_aligned_data['val']['src-text'])}")
print(f"Test segments: {len(non_aligned_data['test']['src-text'])}")
print(f"-"*40)
print("First 5 segments in train split:") # To show variable and original time_steps intervals
for i, (text, audio, visual, label) in enumerate(zip(
        non_aligned_data['train']['src-text'][:3],
        non_aligned_data['train']['src-audio'][:3],
        non_aligned_data['train']['src-visual'][:3],
        non_aligned_data['train']['tgt'][:3])):
    print(f"\nSegment {i+1}:")
    print(f"  Text shape: {text.shape}")
    print(f"  Audio shape: {audio.shape}")
    print(f"  Visual shape: {visual.shape}")
    print(f"  Label shape: {label.shape}")

"""
label: (6) -> [happy, sad, anger, surprise, disgust, fear] 
    averaged from 3 annotators
unaligned:
text: (50, 300)
visual: (500, 35)
audio: (500, 74)  
"""
# Out:
# --------- Non-Aligned Data -------------
# Train segments: 16322
# Validation segments: 1871
# Test segments: 4659
# ----------------------------------------
# First 5 segments in train split:
#
# Segment 1:
#   Text shape: (55, 300)
#   Audio shape: (1781, 74)
#   Visual shape: (535, 35)
#   Label shape: (6,)
#
# Segment 2:
#   Text shape: (22, 300)
#   Audio shape: (539, 74)
#   Visual shape: (162, 35)
#   Label shape: (6,)
#
# Segment 3:
#   Text shape: (23, 300)
#   Audio shape: (922, 74)
#   Visual shape: (277, 35)
#   Label shape: (6,)
# '\nlabel: (6) -> [happy, sad, anger, surprise, disgust, fear] \n    averaged from 3 annotators\nunaligned:\ntext: (50, 300)\nvisual: (500, 35)\naudio: (500, 74)  \n'

# %%
# Save for CARAT
output_path = '../CARAT/data/cmu_mosei_unaligned_ree.pt'
torch.save(non_aligned_data, output_path)

# %%
print("\n--------- Checking labels processing -------------")
print("Checking raw label values before thresholding:")

# Check a few segments from your created dataset
for i in range(3):
    if i < len(non_aligned_data['train']['tgt']):
        label = non_aligned_data['train']['tgt'][i]
        print(f"\nSegment {i+1}:")
        print(f"  Processed label: {label}")
        print(f"  Label sum: {label.sum()}")
        print(f"  Non-zero emotions: {np.count_nonzero(label)}")

# Also check some raw labels before processing
print("\nChecking raw labels from dataset:")
sample_segments = list(dataset[label_field].keys())[:3]
for i, segment in enumerate(sample_segments):
    try:
        raw_label = dataset[label_field][segment]['features'].flatten()
        print(f"\nRaw segment {i+1} ({segment}):")
        print(f"  Raw label: {raw_label}")
        print(f"  Sentiment: {raw_label[0]:.2f}")
        print(f"  Emotions: {raw_label[1:7]}")
        print(f"  Emotions > 0: {raw_label[1:7] > 0.0}")
        print(f"  Emotions > 1: {raw_label[1:7] > 1.5}")
    except Exception as e:
        print(f"Error processing segment {segment}: {e}")
# Out:
# --------- Checking labels processing -------------
# Checking raw label values before thresholding:
#
# Segment 1:
#   Processed label: [1. 1. 0. 0. 0. 1.]
#   Label sum: 3.0
#   Non-zero emotions: 3
#
# Segment 2:
#   Processed label: [0. 0. 0. 0. 0. 0.]
#   Label sum: 0.0
#   Non-zero emotions: 0
#
# Segment 3:
#   Processed label: [1. 1. 0. 0. 0. 1.]
#   Label sum: 3.0
#   Non-zero emotions: 3
#
# Checking raw labels from dataset:
#
# Raw segment 1 (--qXJuDtHPw[0]):
#   Raw label: [1.        0.6666667 0.        0.        0.        0.        0.       ]
#   Sentiment: 1.00
#   Emotions: [0.6666667 0.        0.        0.        0.        0.       ]
#   Emotions > 0: [ True False False False False False]
#   Emotions > 1.5: [False False False False False False]
#
# Raw segment 2 (-3g5yACwYnA[0]):
#   Raw label: [1.        0.6666667 0.6666667 0.        0.        0.        0.6666667]
#   Sentiment: 1.00
#   Emotions: [0.6666667 0.6666667 0.        0.        0.        0.6666667]
#   Emotions > 0: [ True  True False False False  True]
#   Emotions > 1.5: [False False False False False False]
#
# Raw segment 3 (-3g5yACwYnA[1]):
#   Raw label: [0.6666667 0.        0.        0.        0.        0.        0.       ]
#   Sentiment: 0.67
#   Emotions: [0. 0. 0. 0. 0. 0.]
#   Emotions > 0: [False False False False False False]
#   Emotions > 1.5: [False False False False False False]
